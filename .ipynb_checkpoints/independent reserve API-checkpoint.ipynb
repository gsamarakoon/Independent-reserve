# %%
import sys
# !{sys.executable} --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
import sys
# !{sys.executable} -m pip install pyindependentreserve
# Out:
# Requirement already satisfied: pyindependentreserve in c:\users\samar\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: requests==2.14.2 in c:\users\samar\anaconda3\lib\site-packages (from pyindependentreserve) (2.14.2)

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\samar\anaconda3\lib\site-packages (18.1)

# %%
import sys
# !{sys.executable} -m pip install msgpack
# Out:
# Requirement already satisfied: msgpack in c:\users\samar\anaconda3\lib\site-packages (0.5.6)

# %%
import independentreserve as ir
connection = ir.PublicMethods()
connection.get_valid_limit_order_types()
[u'LimitBid', u'LimitOffer']
# Out:
# ['LimitBid', 'LimitOffer']

# %%
from requests.exceptions import HTTPError
import logging


def http_exception_handler(f):
    
    """
    Logs error.
    
    :param error: error being logged
    """
    def log_error(error):
        if hasattr(error, 'message'):
            logging.error(error.message)
        else:
            logging.error(error)
            
    """
    Decorator to keep try catch block dry for all API calls.
    :param f: function being wrapped
    :return:
    """
    def wrapper(*args, **kwargs):
        try:
            response = f(*args, **kwargs)
            response.raise_for_status()
            return response.json()
        except HTTPError as error:
            log_error(error)
        except Exception as error:
            log_error(error)
            
    return wrapper

# %%
"""
Python wrapper for API endpoint documented at https://www.independentreserve.com/API#public
"""

import requests

class PublicMethods(object):
    """
    Python wrapper for API endpoint documented at https://www.independentreserve.com/API#public
    """
    
    """
    Independent Reserve API Url.
    Can override this for testing purposes.
    """
    api_url = "https://api.independentreserve.com"

    def __init__(self, api_url = "https://api.independentreserve.com"):
        PublicMethods.api_url = api_url
        pass


    @staticmethod
    @http_exception_handler
    def get_valid_primary_currency_codes():
        """
        Returns a list of valid primary currency codes. These are the digital currencies which can be traded
        on Independent Reserve.
        This method does not take any parameters.
        :return: list
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidPrimaryCurrencyCodes")
        return response

    @staticmethod
    @http_exception_handler
    def get_valid_secondary_currency_codes():
        """
        Returns a list of valid secondary currency codes. These are the fiat currencies which are supported by
        Independent Reserve for trading purposes.
        :return: list
        ["Usd","Aud", "Nzd"]
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidSecondaryCurrencyCodes")
        return response

    @staticmethod
    @http_exception_handler
    def get_valid_limit_order_types():
        """
        Returns a list of valid limit order types which can be placed onto the Independent Reserve exchange platform.
        :return: list
        ["LimitBid","LimitOffer"]
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidLimitOrderTypes")
        return response

    @staticmethod
    @http_exception_handler
    def get_valid_market_order_types():
        """
        Returns a list of valid market order types which can be placed onto the Independent Reserve exchange platform.
        :return: list
        ["MarketBid","MarketOffer"]
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidMarketOrderTypes")
        return response
        
    @staticmethod
    @http_exception_handler
    def get_valid_order_types():
        """
        Returns a list of valid order types which can be placed onto the Independent Reserve exchange platform.
        :return: list
        ["LimitBid","LimitOffer","MarketBid","MarketOffer"]
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidOrderTypes")
        return response

    @staticmethod
    @http_exception_handler
    def get_valid_transaction_types():
        """
        Returns a list of valid transaction types.
        This method does not take any parameters.
        :return: list
        [u'Brokerage',
         u'Deposit',
         u'DepositFee',
         u'GST',
         u'ReferralCommission',
         u'Trade',
         u'Withdrawal',
         u'WithdrawalFee']
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetValidTransactionTypes")
        return response

    @staticmethod
    @http_exception_handler
    def get_market_summary(primary_currency_code="Xbt", secondary_currency_code="Aud"):
        """
        Returns a current snapshot of the Independent Reserve market for a given currency pair
        This method caches return values for 1 second. Calling it more than once per second will result in cached data
        being returned.
        :param primary_currency_code: Should be of valid code returned by get_valid_primary_currency_code()
        :param secondary_currency_code: Should be of valid code returned by get_valid_secondary_currency_code()
        :return: dict
        {
           "CreatedTimestampUtc ":"2014-08-05T06:42:11.3032208Z",
           "CurrentHighestBidPrice":500.00000000,
           "CurrentLowestOfferPrice":1001.00000000,
           "DayAvgPrice":510.000000,
           "DayHighestPrice":510.00000000,
           "DayLowestPrice":510.00000000,
           "DayVolumeXbt":1.00000000,
           "DayVolumeXbtInSecondaryCurrrency":0.75000000,
           "LastPrice":510.00000000,
           "PrimaryCurrencyCode":"Xbt",
           "SecondaryCurrencyCode":"Usd"
        }
        Return value description
        "CreatedTimestampUtc ": UTC timestamp of when the market summary was generated
        "CurrentHighestBidPrice": Current highest bid on order book
        "CurrentLowestOfferPrice": Current lowest offer on order book
        "DayAvgPrice": Weighted average traded price over last 24 hours
        "DayHighestPrice": Highest traded price over last 24 hours
        "DayLowestPrice": Lowest traded price over last 24 hours
        "DayVolumeXbt": Volume of primary currency traded in last 24 hours
        "DayVolumeXbtInSecondaryCurrrency": Volume of primary currency traded in last 24 hours for chosen secondary
                                            currency
        "LastPrice": Last traded price
        "PrimaryCurrencyCode": The primary currency being summarised
        "SecondaryCurrencyCode": The secondary currency being used for pricing
        """
        response = requests.get(
            PublicMethods.api_url + "/Public/GetMarketSummary?primaryCurrencyCode={0}&secondaryCurrencyCode={1}".format(
                primary_currency_code, secondary_currency_code))
        return response

    @staticmethod
    @http_exception_handler
    def get_order_book(primary_currency_code="Xbt", secondary_currency_code="Aud"):
        """
        Returns the Order Book for a given currency pair.
        This method caches return values for 1 second. Calling it more than once per second will result in cached
        data being returned.
        :return: dict
        {
           "BuyOrders":[
              {
                 "OrderType":"LimitBid",
                 "Price":497.02000000,
                 "Volume":0.01000000
              },
              {
                 "OrderType":"LimitBid",
                 "Price":490.00000000,
                 "Volume":1.00000000
              }
           ],
           "CreatedTimestampUtc ":"2014-08-05T06:42:11.3032208Z",
           "PrimaryCurrencyCode":"Xbt",
           "SecondaryCurrencyCode":"Usd",
           "SellOrders":[
              {
                 "OrderType":"LimitOffer",
                 "Price":500.00000000,
                 "Volume":1.00000000
              },
              {
                 "OrderType":"LimitOffer",
                 "Price":505.00000000,
                 "Volume":1.00000000
              }
           ]
        }
        """
        response = requests.get(
            PublicMethods.api_url + "/Public/GetOrderBook?primaryCurrencyCode={0}&secondaryCurrencyCode={1}"
                .format(primary_currency_code, secondary_currency_code))
        return response

    @staticmethod
    @http_exception_handler
    def get_trade_history_summary(primary_currency_code="Eth", secondary_currency_code="Usd", hours="240"):
        """
        Returns summarised historical trading data for a given currency pair. Data is summarised into 1 hour intervals.
        :param primary_currency_code: The digital currency for which to retrieve trade history.
                                      Must be a valid primary currency, which can be checked via the
                                      GetValidPrimaryCurrencyCodes method.
        :param secondary_currency_code: The fiat currency in which to retrieve trade history.
                                        Must be a valid secondary currency, which can be checked via the
                                        GetValidSecondaryCurrencyCodes method.
        :param hours: The time period in hours to get trade history.
        :return: dict
        Notes
        This method caches return values for 30 minutes. Calling it more than once per 30 minutes will result in cached
        data being returned.
        {
           "CreatedTimestampUtc ":"2014-08-05T09:02:57.5440691Z",
           "HistorySummaryItems":[{
                "AverageSecondaryCurrencyPrice":510.00000000,
                "ClosingSecondaryCurrencyPrice":510.00000000,
                "StartTimestampUtc":"2014-08-04T09:00:00Z"
                "EndTimestampUtc":"2014-08-04T10:00:00Z",
                "HighestSecondaryCurrencyPrice":510.00000000,
                "LowestSecondaryCurrencyPrice":510.00000000,
                "NumberOfTrades":0,
                "OpeningSecondaryCurrencyPrice":510.00000000,
                "PrimaryCurrencyVolume":0.00000000,
                "SecondaryCurrencyVolume":0.00000000,
            }],
           "NumberOfHoursInThePastToRetrieve":1,
           "PrimaryCurrencyCode":"Xbt",
           "SecondaryCurrencyCode":"Usd"
        }
        Return value descriptions
        "CreatedTimestampUtc ":UTC timestamp of when the data was generated,
        "HistorySummaryItems":[ List of hourly summary blocks
        {
            "AverageSecondaryCurrencyPrice": Average traded price during hour
            "ClosingSecondaryCurrencyPrice": Last traded price in hour
            "StartTimestampUtc": UTC Start time of hour
            "EndTimestampUtc": UTC End time of hour
            "HighestSecondaryCurrencyPrice": Highest traded price during hour
            "LowestSecondaryCurrencyPrice": Lowest traded price during hour
            "NumberOfTrades":Number of trades executed during hour
            "OpeningSecondaryCurrencyPrice": Opening traded price at start of hour
            "PrimaryCurrencyVolume": Volume of primary currency trade during hour
            "SecondaryCurrencyVolume": Volume of secondary currency traded during hour
        }],
        "NumberOfHoursInThePastToRetrieve": Number of past hours being returned,
        "PrimaryCurrencyCode": The primary currency being shown
        "SecondaryCurrencyCode": The secondary currency being used for pricing
        """

        response = requests.get(
            PublicMethods.api_url + "/Public/GetTradeHistorySummary?primaryCurrencyCode={0}&secondaryCurrencyCode={1}&numberOfHoursInThePastToRetrieve={2}".format(
                primary_currency_code, secondary_currency_code, hours)
        )
        return response

    @staticmethod
    @http_exception_handler
    def get_recent_trades(primary_currency_code="Xbt", secondary_currency_code="Usd", number_of_trades=50):
        """
        :param primary_currency_code: The digital currency for which to retrieve recent trades.
                                      Must be a valid primary currency, which can be checked via the
                                      GetValidPrimaryCurrencyCodes method.
        :param secondary_currency_code: The fiat currency in which to retrieve recent trades.
                                        Must be a valid secondary currency, which can be checked via the
                                        GetValidSecondaryCurrencyCodes method.
        :param number_of_trades: How many recent trades to retrieve (maximum is 50)
        :return: dict
        Notes
        This method caches return values for 1 second. Calling it more than once per second will result in cached data
        being returned.
        {
           "CreatedTimestampUtc ":"2014-08-05T09:14:39.4830696Z",
           "PrimaryCurrencyCode":"Xbt",
           "SecondaryCurrencyCode":"Usd",
           "Trades":[
              {
                 "PrimaryCurrencyAmount":1.00000000,
                 "SecondaryCurrencyTradePrice":510.00000000,
                 "TradeTimestampUtc":"2014-07-31T10:34:05.935412Z"
              },
              {
                 "PrimaryCurrencyAmount":0.01000000,
                 "SecondaryCurrencyTradePrice":501.000000,
                 "TradeTimestampUtc":"2014-07-31T10:33:24.8458426Z"
              }
           ]
        }
        Return value descriptions
        "CreatedTimestampUtc ":UTC timestamp of when the data was generated
        "PrimaryCurrencyCode": The primary currency being shown
        "SecondaryCurrencyCode": The secondary currency being used for pricing
        "Trades":[  List of individual trades
        {
            "PrimaryCurrencyAmount": Amount traded in primary currency
            "SecondaryCurrencyTradePrice": Amount traded in secondary currency
            "TradeTimestampUtc": UTC timestamp of trade
        }]
        """

        response = requests.get(
            PublicMethods.api_url + "/Public/GetRecentTrades?primaryCurrencyCode={0}&secondaryCurrencyCode={1}&numberOfRecentTradesToRetrieve={2}".format(
                primary_currency_code, secondary_currency_code, number_of_trades)
        )
        return response

    @staticmethod
    @http_exception_handler
    def get_fx_rates():
        """
        Returns a list of exchange rates used by Independing Reserve when depositing funds or withdrawing funds from
        accounts.
        :return: list
        """
        response = requests.get(PublicMethods.api_url + "/Public/GetFxRates")
        return response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-374cd38f5132> in <module>()
#       5 import requests
#       6
# ----> 7 class PublicMethods(object):
#       8     """
#       9     Python wrapper for API endpoint documented at https://www.independentreserve.com/API#public
#
# <ipython-input-1-374cd38f5132> in PublicMethods()
#      22
#      23     @staticmethod
# ---> 24     @http_exception_handler
#      25     def get_valid_primary_currency_codes():
#      26         """
#
# NameError: name 'http_exception_handler' is not defined

# %%
import independentreserve as ir
connection = ir.PublicMethods()
connection.get_trade_history_summary()
# Out:
# {'HistorySummaryItems': [{'StartTimestampUtc': '2018-10-06T00:00:00Z',
#    'EndTimestampUtc': '2018-10-06T01:00:00Z',
#    'PrimaryCurrencyVolume': 3.10405178,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 19,
#    'HighestSecondaryCurrencyPrice': 9349.99,
#    'LowestSecondaryCurrencyPrice': 9295.21,
#    'OpeningSecondaryCurrencyPrice': 9330.0,
#    'ClosingSecondaryCurrencyPrice': 9338.7,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T01:00:00Z',
#    'EndTimestampUtc': '2018-10-06T02:00:00Z',
#    'PrimaryCurrencyVolume': 1.96265538,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 11,
#    'HighestSecondaryCurrencyPrice': 9311.0,
#    'LowestSecondaryCurrencyPrice': 9262.41,
#    'OpeningSecondaryCurrencyPrice': 9338.7,
#    'ClosingSecondaryCurrencyPrice': 9272.04,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T02:00:00Z',
#    'EndTimestampUtc': '2018-10-06T03:00:00Z',
#    'PrimaryCurrencyVolume': 3.07037397,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 9315.82,
#    'LowestSecondaryCurrencyPrice': 9246.8,
#    'OpeningSecondaryCurrencyPrice': 9272.04,
#    'ClosingSecondaryCurrencyPrice': 9315.82,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T03:00:00Z',
#    'EndTimestampUtc': '2018-10-06T04:00:00Z',
#    'PrimaryCurrencyVolume': 2.05293501,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9290.0,
#    'LowestSecondaryCurrencyPrice': 9257.96,
#    'OpeningSecondaryCurrencyPrice': 9315.82,
#    'ClosingSecondaryCurrencyPrice': 9290.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T04:00:00Z',
#    'EndTimestampUtc': '2018-10-06T05:00:00Z',
#    'PrimaryCurrencyVolume': 2.67798712,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 7,
#    'HighestSecondaryCurrencyPrice': 9290.0,
#    'LowestSecondaryCurrencyPrice': 9240.01,
#    'OpeningSecondaryCurrencyPrice': 9290.0,
#    'ClosingSecondaryCurrencyPrice': 9290.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T05:00:00Z',
#    'EndTimestampUtc': '2018-10-06T06:00:00Z',
#    'PrimaryCurrencyVolume': 0.224564,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9265.89,
#    'LowestSecondaryCurrencyPrice': 9261.37,
#    'OpeningSecondaryCurrencyPrice': 9290.0,
#    'ClosingSecondaryCurrencyPrice': 9265.89,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T06:00:00Z',
#    'EndTimestampUtc': '2018-10-06T07:00:00Z',
#    'PrimaryCurrencyVolume': 0.85577392,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9290.0,
#    'LowestSecondaryCurrencyPrice': 9287.36,
#    'OpeningSecondaryCurrencyPrice': 9265.89,
#    'ClosingSecondaryCurrencyPrice': 9287.36,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T07:00:00Z',
#    'EndTimestampUtc': '2018-10-06T08:00:00Z',
#    'PrimaryCurrencyVolume': 0.55660511,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 9290.0,
#    'LowestSecondaryCurrencyPrice': 9287.43,
#    'OpeningSecondaryCurrencyPrice': 9287.36,
#    'ClosingSecondaryCurrencyPrice': 9287.43,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T08:00:00Z',
#    'EndTimestampUtc': '2018-10-06T09:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9287.43,
#    'LowestSecondaryCurrencyPrice': 9287.43,
#    'OpeningSecondaryCurrencyPrice': 9287.43,
#    'ClosingSecondaryCurrencyPrice': 9287.43,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T09:00:00Z',
#    'EndTimestampUtc': '2018-10-06T10:00:00Z',
#    'PrimaryCurrencyVolume': 0.5354436,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9290.0,
#    'LowestSecondaryCurrencyPrice': 9287.36,
#    'OpeningSecondaryCurrencyPrice': 9287.43,
#    'ClosingSecondaryCurrencyPrice': 9290.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T10:00:00Z',
#    'EndTimestampUtc': '2018-10-06T11:00:00Z',
#    'PrimaryCurrencyVolume': 2.46,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9320.96,
#    'LowestSecondaryCurrencyPrice': 9298.0,
#    'OpeningSecondaryCurrencyPrice': 9290.0,
#    'ClosingSecondaryCurrencyPrice': 9320.96,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T11:00:00Z',
#    'EndTimestampUtc': '2018-10-06T12:00:00Z',
#    'PrimaryCurrencyVolume': 3.64940004,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9290.4,
#    'LowestSecondaryCurrencyPrice': 9287.37,
#    'OpeningSecondaryCurrencyPrice': 9320.96,
#    'ClosingSecondaryCurrencyPrice': 9287.37,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T12:00:00Z',
#    'EndTimestampUtc': '2018-10-06T13:00:00Z',
#    'PrimaryCurrencyVolume': 0.29259689,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9281.32,
#    'LowestSecondaryCurrencyPrice': 9251.94,
#    'OpeningSecondaryCurrencyPrice': 9287.37,
#    'ClosingSecondaryCurrencyPrice': 9281.32,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T13:00:00Z',
#    'EndTimestampUtc': '2018-10-06T14:00:00Z',
#    'PrimaryCurrencyVolume': 0.78209606,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9248.52,
#    'LowestSecondaryCurrencyPrice': 9248.44,
#    'OpeningSecondaryCurrencyPrice': 9281.32,
#    'ClosingSecondaryCurrencyPrice': 9248.44,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T14:00:00Z',
#    'EndTimestampUtc': '2018-10-06T15:00:00Z',
#    'PrimaryCurrencyVolume': 1.18805872,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9291.03,
#    'LowestSecondaryCurrencyPrice': 9246.87,
#    'OpeningSecondaryCurrencyPrice': 9248.44,
#    'ClosingSecondaryCurrencyPrice': 9246.87,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T15:00:00Z',
#    'EndTimestampUtc': '2018-10-06T16:00:00Z',
#    'PrimaryCurrencyVolume': 0.03309573,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9296.39,
#    'LowestSecondaryCurrencyPrice': 9296.39,
#    'OpeningSecondaryCurrencyPrice': 9246.87,
#    'ClosingSecondaryCurrencyPrice': 9296.39,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T16:00:00Z',
#    'EndTimestampUtc': '2018-10-06T17:00:00Z',
#    'PrimaryCurrencyVolume': 0.39543957,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9289.43,
#    'LowestSecondaryCurrencyPrice': 9256.13,
#    'OpeningSecondaryCurrencyPrice': 9296.39,
#    'ClosingSecondaryCurrencyPrice': 9280.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T17:00:00Z',
#    'EndTimestampUtc': '2018-10-06T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9280.0,
#    'LowestSecondaryCurrencyPrice': 9280.0,
#    'OpeningSecondaryCurrencyPrice': 9280.0,
#    'ClosingSecondaryCurrencyPrice': 9280.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T18:00:00Z',
#    'EndTimestampUtc': '2018-10-06T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9280.0,
#    'LowestSecondaryCurrencyPrice': 9280.0,
#    'OpeningSecondaryCurrencyPrice': 9280.0,
#    'ClosingSecondaryCurrencyPrice': 9280.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T19:00:00Z',
#    'EndTimestampUtc': '2018-10-06T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9280.0,
#    'LowestSecondaryCurrencyPrice': 9280.0,
#    'OpeningSecondaryCurrencyPrice': 9280.0,
#    'ClosingSecondaryCurrencyPrice': 9280.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T20:00:00Z',
#    'EndTimestampUtc': '2018-10-06T21:00:00Z',
#    'PrimaryCurrencyVolume': 0.02658,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9291.63,
#    'LowestSecondaryCurrencyPrice': 9247.74,
#    'OpeningSecondaryCurrencyPrice': 9280.0,
#    'ClosingSecondaryCurrencyPrice': 9291.63,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T21:00:00Z',
#    'EndTimestampUtc': '2018-10-06T22:00:00Z',
#    'PrimaryCurrencyVolume': 0.14048026,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9329.8,
#    'LowestSecondaryCurrencyPrice': 9322.46,
#    'OpeningSecondaryCurrencyPrice': 9291.63,
#    'ClosingSecondaryCurrencyPrice': 9322.47,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T22:00:00Z',
#    'EndTimestampUtc': '2018-10-06T23:00:00Z',
#    'PrimaryCurrencyVolume': 0.04707688,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9299.98,
#    'LowestSecondaryCurrencyPrice': 9299.98,
#    'OpeningSecondaryCurrencyPrice': 9322.47,
#    'ClosingSecondaryCurrencyPrice': 9299.98,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-06T23:00:00Z',
#    'EndTimestampUtc': '2018-10-07T00:00:00Z',
#    'PrimaryCurrencyVolume': 0.08,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9300.0,
#    'LowestSecondaryCurrencyPrice': 9300.0,
#    'OpeningSecondaryCurrencyPrice': 9299.98,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T00:00:00Z',
#    'EndTimestampUtc': '2018-10-07T01:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9300.0,
#    'LowestSecondaryCurrencyPrice': 9300.0,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T01:00:00Z',
#    'EndTimestampUtc': '2018-10-07T02:00:00Z',
#    'PrimaryCurrencyVolume': 1.3075784,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9300.0,
#    'LowestSecondaryCurrencyPrice': 9266.1,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T02:00:00Z',
#    'EndTimestampUtc': '2018-10-07T03:00:00Z',
#    'PrimaryCurrencyVolume': 0.50865416,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9300.0,
#    'LowestSecondaryCurrencyPrice': 9290.8,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T03:00:00Z',
#    'EndTimestampUtc': '2018-10-07T04:00:00Z',
#    'PrimaryCurrencyVolume': 0.60750279,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9300.0,
#    'LowestSecondaryCurrencyPrice': 9285.0,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T04:00:00Z',
#    'EndTimestampUtc': '2018-10-07T05:00:00Z',
#    'PrimaryCurrencyVolume': 0.80997216,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9314.64,
#    'LowestSecondaryCurrencyPrice': 9285.54,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9285.54,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T05:00:00Z',
#    'EndTimestampUtc': '2018-10-07T06:00:00Z',
#    'PrimaryCurrencyVolume': 0.54046435,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9302.79,
#    'LowestSecondaryCurrencyPrice': 9267.19,
#    'OpeningSecondaryCurrencyPrice': 9285.54,
#    'ClosingSecondaryCurrencyPrice': 9272.04,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T06:00:00Z',
#    'EndTimestampUtc': '2018-10-07T07:00:00Z',
#    'PrimaryCurrencyVolume': 0.05251309,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9300.08,
#    'LowestSecondaryCurrencyPrice': 9300.08,
#    'OpeningSecondaryCurrencyPrice': 9272.04,
#    'ClosingSecondaryCurrencyPrice': 9300.08,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T07:00:00Z',
#    'EndTimestampUtc': '2018-10-07T08:00:00Z',
#    'PrimaryCurrencyVolume': 0.10795733,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9288.78,
#    'LowestSecondaryCurrencyPrice': 9251.06,
#    'OpeningSecondaryCurrencyPrice': 9300.08,
#    'ClosingSecondaryCurrencyPrice': 9280.98,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T08:00:00Z',
#    'EndTimestampUtc': '2018-10-07T09:00:00Z',
#    'PrimaryCurrencyVolume': 4.06494577,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 9,
#    'HighestSecondaryCurrencyPrice': 9246.73,
#    'LowestSecondaryCurrencyPrice': 9200.0,
#    'OpeningSecondaryCurrencyPrice': 9280.98,
#    'ClosingSecondaryCurrencyPrice': 9244.67,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T09:00:00Z',
#    'EndTimestampUtc': '2018-10-07T10:00:00Z',
#    'PrimaryCurrencyVolume': 1.68180331,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 9242.49,
#    'LowestSecondaryCurrencyPrice': 9200.0,
#    'OpeningSecondaryCurrencyPrice': 9244.67,
#    'ClosingSecondaryCurrencyPrice': 9242.49,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T10:00:00Z',
#    'EndTimestampUtc': '2018-10-07T11:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9242.49,
#    'LowestSecondaryCurrencyPrice': 9242.49,
#    'OpeningSecondaryCurrencyPrice': 9242.49,
#    'ClosingSecondaryCurrencyPrice': 9242.49,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T11:00:00Z',
#    'EndTimestampUtc': '2018-10-07T12:00:00Z',
#    'PrimaryCurrencyVolume': 2.27034594,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 7,
#    'HighestSecondaryCurrencyPrice': 9207.74,
#    'LowestSecondaryCurrencyPrice': 9201.12,
#    'OpeningSecondaryCurrencyPrice': 9242.49,
#    'ClosingSecondaryCurrencyPrice': 9202.01,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T12:00:00Z',
#    'EndTimestampUtc': '2018-10-07T13:00:00Z',
#    'PrimaryCurrencyVolume': 0.38329667,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 7,
#    'HighestSecondaryCurrencyPrice': 9244.8,
#    'LowestSecondaryCurrencyPrice': 9201.11,
#    'OpeningSecondaryCurrencyPrice': 9202.01,
#    'ClosingSecondaryCurrencyPrice': 9244.8,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T13:00:00Z',
#    'EndTimestampUtc': '2018-10-07T14:00:00Z',
#    'PrimaryCurrencyVolume': 0.21518895,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9249.67,
#    'LowestSecondaryCurrencyPrice': 9249.67,
#    'OpeningSecondaryCurrencyPrice': 9244.8,
#    'ClosingSecondaryCurrencyPrice': 9249.67,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T14:00:00Z',
#    'EndTimestampUtc': '2018-10-07T15:00:00Z',
#    'PrimaryCurrencyVolume': 0.0161525,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9204.93,
#    'LowestSecondaryCurrencyPrice': 9204.93,
#    'OpeningSecondaryCurrencyPrice': 9249.67,
#    'ClosingSecondaryCurrencyPrice': 9204.93,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T15:00:00Z',
#    'EndTimestampUtc': '2018-10-07T16:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9204.93,
#    'LowestSecondaryCurrencyPrice': 9204.93,
#    'OpeningSecondaryCurrencyPrice': 9204.93,
#    'ClosingSecondaryCurrencyPrice': 9204.93,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T16:00:00Z',
#    'EndTimestampUtc': '2018-10-07T17:00:00Z',
#    'PrimaryCurrencyVolume': 0.02595,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9249.97,
#    'LowestSecondaryCurrencyPrice': 9249.97,
#    'OpeningSecondaryCurrencyPrice': 9204.93,
#    'ClosingSecondaryCurrencyPrice': 9249.97,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T17:00:00Z',
#    'EndTimestampUtc': '2018-10-07T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9249.97,
#    'LowestSecondaryCurrencyPrice': 9249.97,
#    'OpeningSecondaryCurrencyPrice': 9249.97,
#    'ClosingSecondaryCurrencyPrice': 9249.97,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T18:00:00Z',
#    'EndTimestampUtc': '2018-10-07T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.04151407,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 9250.0,
#    'LowestSecondaryCurrencyPrice': 9250.0,
#    'OpeningSecondaryCurrencyPrice': 9249.97,
#    'ClosingSecondaryCurrencyPrice': 9250.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T19:00:00Z',
#    'EndTimestampUtc': '2018-10-07T20:00:00Z',
#    'PrimaryCurrencyVolume': 1.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 9275.17,
#    'LowestSecondaryCurrencyPrice': 9250.0,
#    'OpeningSecondaryCurrencyPrice': 9250.0,
#    'ClosingSecondaryCurrencyPrice': 9275.17,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T20:00:00Z',
#    'EndTimestampUtc': '2018-10-07T21:00:00Z',
#    'PrimaryCurrencyVolume': 1.2425,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9277.59,
#    'LowestSecondaryCurrencyPrice': 9227.75,
#    'OpeningSecondaryCurrencyPrice': 9275.17,
#    'ClosingSecondaryCurrencyPrice': 9227.75,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T21:00:00Z',
#    'EndTimestampUtc': '2018-10-07T22:00:00Z',
#    'PrimaryCurrencyVolume': 0.23528217,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 9281.37,
#    'LowestSecondaryCurrencyPrice': 9274.42,
#    'OpeningSecondaryCurrencyPrice': 9227.75,
#    'ClosingSecondaryCurrencyPrice': 9281.37,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T22:00:00Z',
#    'EndTimestampUtc': '2018-10-07T23:00:00Z',
#    'PrimaryCurrencyVolume': 1.04365491,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 9281.38,
#    'LowestSecondaryCurrencyPrice': 9238.9,
#    'OpeningSecondaryCurrencyPrice': 9281.37,
#    'ClosingSecondaryCurrencyPrice': 9275.37,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-07T23:00:00Z',
#    'EndTimestampUtc': '2018-10-08T00:00:00Z',
#    'PrimaryCurrencyVolume': 1.58822409,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 16,
#    'HighestSecondaryCurrencyPrice': 9337.37,
#    'LowestSecondaryCurrencyPrice': 9250.45,
#    'OpeningSecondaryCurrencyPrice': 9275.37,
#    'ClosingSecondaryCurrencyPrice': 9296.41,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T00:00:00Z',
#    'EndTimestampUtc': '2018-10-08T01:00:00Z',
#    'PrimaryCurrencyVolume': 0.12358919,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9328.74,
#    'LowestSecondaryCurrencyPrice': 9286.38,
#    'OpeningSecondaryCurrencyPrice': 9296.41,
#    'ClosingSecondaryCurrencyPrice': 9286.38,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T01:00:00Z',
#    'EndTimestampUtc': '2018-10-08T02:00:00Z',
#    'PrimaryCurrencyVolume': 2.11312192,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 9316.53,
#    'LowestSecondaryCurrencyPrice': 9273.1,
#    'OpeningSecondaryCurrencyPrice': 9286.38,
#    'ClosingSecondaryCurrencyPrice': 9273.1,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T02:00:00Z',
#    'EndTimestampUtc': '2018-10-08T03:00:00Z',
#    'PrimaryCurrencyVolume': 1.37828067,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 9317.19,
#    'LowestSecondaryCurrencyPrice': 9273.1,
#    'OpeningSecondaryCurrencyPrice': 9273.1,
#    'ClosingSecondaryCurrencyPrice': 9279.4,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T03:00:00Z',
#    'EndTimestampUtc': '2018-10-08T04:00:00Z',
#    'PrimaryCurrencyVolume': 18.89280359,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 24,
#    'HighestSecondaryCurrencyPrice': 9284.03,
#    'LowestSecondaryCurrencyPrice': 9256.04,
#    'OpeningSecondaryCurrencyPrice': 9279.4,
#    'ClosingSecondaryCurrencyPrice': 9264.02,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T04:00:00Z',
#    'EndTimestampUtc': '2018-10-08T05:00:00Z',
#    'PrimaryCurrencyVolume': 1.86396507,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 9300.14,
#    'LowestSecondaryCurrencyPrice': 9267.95,
#    'OpeningSecondaryCurrencyPrice': 9264.02,
#    'ClosingSecondaryCurrencyPrice': 9267.95,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T05:00:00Z',
#    'EndTimestampUtc': '2018-10-08T06:00:00Z',
#    'PrimaryCurrencyVolume': 5.84170476,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 9280.0,
#    'LowestSecondaryCurrencyPrice': 9240.93,
#    'OpeningSecondaryCurrencyPrice': 9267.95,
#    'ClosingSecondaryCurrencyPrice': 9250.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T06:00:00Z',
#    'EndTimestampUtc': '2018-10-08T07:00:00Z',
#    'PrimaryCurrencyVolume': 2.159915,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 12,
#    'HighestSecondaryCurrencyPrice': 9250.0,
#    'LowestSecondaryCurrencyPrice': 9245.09,
#    'OpeningSecondaryCurrencyPrice': 9250.0,
#    'ClosingSecondaryCurrencyPrice': 9250.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T07:00:00Z',
#    'EndTimestampUtc': '2018-10-08T08:00:00Z',
#    'PrimaryCurrencyVolume': 14.711625,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 19,
#    'HighestSecondaryCurrencyPrice': 9250.0,
#    'LowestSecondaryCurrencyPrice': 9249.83,
#    'OpeningSecondaryCurrencyPrice': 9250.0,
#    'ClosingSecondaryCurrencyPrice': 9250.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T08:00:00Z',
#    'EndTimestampUtc': '2018-10-08T09:00:00Z',
#    'PrimaryCurrencyVolume': 1.14807088,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9280.0,
#    'LowestSecondaryCurrencyPrice': 9269.51,
#    'OpeningSecondaryCurrencyPrice': 9250.0,
#    'ClosingSecondaryCurrencyPrice': 9280.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T09:00:00Z',
#    'EndTimestampUtc': '2018-10-08T10:00:00Z',
#    'PrimaryCurrencyVolume': 19.99759859,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 17,
#    'HighestSecondaryCurrencyPrice': 9259.9,
#    'LowestSecondaryCurrencyPrice': 9208.01,
#    'OpeningSecondaryCurrencyPrice': 9280.0,
#    'ClosingSecondaryCurrencyPrice': 9212.3,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T10:00:00Z',
#    'EndTimestampUtc': '2018-10-08T11:00:00Z',
#    'PrimaryCurrencyVolume': 5.09398205,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 11,
#    'HighestSecondaryCurrencyPrice': 9249.43,
#    'LowestSecondaryCurrencyPrice': 9216.9,
#    'OpeningSecondaryCurrencyPrice': 9212.3,
#    'ClosingSecondaryCurrencyPrice': 9247.99,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T11:00:00Z',
#    'EndTimestampUtc': '2018-10-08T12:00:00Z',
#    'PrimaryCurrencyVolume': 11.01255161,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 103,
#    'HighestSecondaryCurrencyPrice': 9316.9,
#    'LowestSecondaryCurrencyPrice': 9248.0,
#    'OpeningSecondaryCurrencyPrice': 9247.99,
#    'ClosingSecondaryCurrencyPrice': 9316.9,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T12:00:00Z',
#    'EndTimestampUtc': '2018-10-08T13:00:00Z',
#    'PrimaryCurrencyVolume': 1.16100957,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 9360.0,
#    'LowestSecondaryCurrencyPrice': 9321.0,
#    'OpeningSecondaryCurrencyPrice': 9316.9,
#    'ClosingSecondaryCurrencyPrice': 9338.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T13:00:00Z',
#    'EndTimestampUtc': '2018-10-08T14:00:00Z',
#    'PrimaryCurrencyVolume': 0.41382525,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9304.9,
#    'LowestSecondaryCurrencyPrice': 9300.0,
#    'OpeningSecondaryCurrencyPrice': 9338.0,
#    'ClosingSecondaryCurrencyPrice': 9300.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T14:00:00Z',
#    'EndTimestampUtc': '2018-10-08T15:00:00Z',
#    'PrimaryCurrencyVolume': 2.06005721,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9328.16,
#    'LowestSecondaryCurrencyPrice': 9259.0,
#    'OpeningSecondaryCurrencyPrice': 9300.0,
#    'ClosingSecondaryCurrencyPrice': 9328.16,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T15:00:00Z',
#    'EndTimestampUtc': '2018-10-08T16:00:00Z',
#    'PrimaryCurrencyVolume': 2.37,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9338.0,
#    'LowestSecondaryCurrencyPrice': 9328.21,
#    'OpeningSecondaryCurrencyPrice': 9328.16,
#    'ClosingSecondaryCurrencyPrice': 9337.99,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T16:00:00Z',
#    'EndTimestampUtc': '2018-10-08T17:00:00Z',
#    'PrimaryCurrencyVolume': 3.5,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9282.2,
#    'LowestSecondaryCurrencyPrice': 9227.66,
#    'OpeningSecondaryCurrencyPrice': 9337.99,
#    'ClosingSecondaryCurrencyPrice': 9227.66,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T17:00:00Z',
#    'EndTimestampUtc': '2018-10-08T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9227.66,
#    'LowestSecondaryCurrencyPrice': 9227.66,
#    'OpeningSecondaryCurrencyPrice': 9227.66,
#    'ClosingSecondaryCurrencyPrice': 9227.66,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T18:00:00Z',
#    'EndTimestampUtc': '2018-10-08T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9227.66,
#    'LowestSecondaryCurrencyPrice': 9227.66,
#    'OpeningSecondaryCurrencyPrice': 9227.66,
#    'ClosingSecondaryCurrencyPrice': 9227.66,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T19:00:00Z',
#    'EndTimestampUtc': '2018-10-08T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.0486393,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9337.92,
#    'LowestSecondaryCurrencyPrice': 9337.92,
#    'OpeningSecondaryCurrencyPrice': 9227.66,
#    'ClosingSecondaryCurrencyPrice': 9337.92,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T20:00:00Z',
#    'EndTimestampUtc': '2018-10-08T21:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9337.92,
#    'LowestSecondaryCurrencyPrice': 9337.92,
#    'OpeningSecondaryCurrencyPrice': 9337.92,
#    'ClosingSecondaryCurrencyPrice': 9337.92,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T21:00:00Z',
#    'EndTimestampUtc': '2018-10-08T22:00:00Z',
#    'PrimaryCurrencyVolume': 4.36194193,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 14,
#    'HighestSecondaryCurrencyPrice': 9334.99,
#    'LowestSecondaryCurrencyPrice': 9243.16,
#    'OpeningSecondaryCurrencyPrice': 9337.92,
#    'ClosingSecondaryCurrencyPrice': 9330.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T22:00:00Z',
#    'EndTimestampUtc': '2018-10-08T23:00:00Z',
#    'PrimaryCurrencyVolume': 8.1232523,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 26,
#    'HighestSecondaryCurrencyPrice': 9329.15,
#    'LowestSecondaryCurrencyPrice': 9270.5,
#    'OpeningSecondaryCurrencyPrice': 9330.0,
#    'ClosingSecondaryCurrencyPrice': 9309.98,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-08T23:00:00Z',
#    'EndTimestampUtc': '2018-10-09T00:00:00Z',
#    'PrimaryCurrencyVolume': 4.82640664,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 17,
#    'HighestSecondaryCurrencyPrice': 9329.05,
#    'LowestSecondaryCurrencyPrice': 9306.36,
#    'OpeningSecondaryCurrencyPrice': 9309.98,
#    'ClosingSecondaryCurrencyPrice': 9318.58,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T00:00:00Z',
#    'EndTimestampUtc': '2018-10-09T01:00:00Z',
#    'PrimaryCurrencyVolume': 7.70717756,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 25,
#    'HighestSecondaryCurrencyPrice': 9335.0,
#    'LowestSecondaryCurrencyPrice': 9326.35,
#    'OpeningSecondaryCurrencyPrice': 9318.58,
#    'ClosingSecondaryCurrencyPrice': 9334.99,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T01:00:00Z',
#    'EndTimestampUtc': '2018-10-09T02:00:00Z',
#    'PrimaryCurrencyVolume': 7.29537288,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 16,
#    'HighestSecondaryCurrencyPrice': 9334.51,
#    'LowestSecondaryCurrencyPrice': 9269.94,
#    'OpeningSecondaryCurrencyPrice': 9334.99,
#    'ClosingSecondaryCurrencyPrice': 9328.57,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T02:00:00Z',
#    'EndTimestampUtc': '2018-10-09T03:00:00Z',
#    'PrimaryCurrencyVolume': 4.95352655,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 22,
#    'HighestSecondaryCurrencyPrice': 9332.47,
#    'LowestSecondaryCurrencyPrice': 9278.87,
#    'OpeningSecondaryCurrencyPrice': 9328.57,
#    'ClosingSecondaryCurrencyPrice': 9317.56,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T03:00:00Z',
#    'EndTimestampUtc': '2018-10-09T04:00:00Z',
#    'PrimaryCurrencyVolume': 7.70523455,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 9324.63,
#    'LowestSecondaryCurrencyPrice': 9283.0,
#    'OpeningSecondaryCurrencyPrice': 9317.56,
#    'ClosingSecondaryCurrencyPrice': 9295.64,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T04:00:00Z',
#    'EndTimestampUtc': '2018-10-09T05:00:00Z',
#    'PrimaryCurrencyVolume': 4.78624379,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9321.77,
#    'LowestSecondaryCurrencyPrice': 9289.96,
#    'OpeningSecondaryCurrencyPrice': 9295.64,
#    'ClosingSecondaryCurrencyPrice': 9291.15,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T05:00:00Z',
#    'EndTimestampUtc': '2018-10-09T06:00:00Z',
#    'PrimaryCurrencyVolume': 1.0139718,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9310.0,
#    'LowestSecondaryCurrencyPrice': 9289.99,
#    'OpeningSecondaryCurrencyPrice': 9291.15,
#    'ClosingSecondaryCurrencyPrice': 9310.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T06:00:00Z',
#    'EndTimestampUtc': '2018-10-09T07:00:00Z',
#    'PrimaryCurrencyVolume': 1.6888771,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9326.2,
#    'LowestSecondaryCurrencyPrice': 9310.0,
#    'OpeningSecondaryCurrencyPrice': 9310.0,
#    'ClosingSecondaryCurrencyPrice': 9326.2,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T07:00:00Z',
#    'EndTimestampUtc': '2018-10-09T08:00:00Z',
#    'PrimaryCurrencyVolume': 1.56438221,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 12,
#    'HighestSecondaryCurrencyPrice': 9333.58,
#    'LowestSecondaryCurrencyPrice': 9310.0,
#    'OpeningSecondaryCurrencyPrice': 9326.2,
#    'ClosingSecondaryCurrencyPrice': 9310.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T08:00:00Z',
#    'EndTimestampUtc': '2018-10-09T09:00:00Z',
#    'PrimaryCurrencyVolume': 2.47477411,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 9341.01,
#    'LowestSecondaryCurrencyPrice': 9272.68,
#    'OpeningSecondaryCurrencyPrice': 9310.0,
#    'ClosingSecondaryCurrencyPrice': 9313.04,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T09:00:00Z',
#    'EndTimestampUtc': '2018-10-09T10:00:00Z',
#    'PrimaryCurrencyVolume': 1.50768937,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 9,
#    'HighestSecondaryCurrencyPrice': 9324.97,
#    'LowestSecondaryCurrencyPrice': 9284.84,
#    'OpeningSecondaryCurrencyPrice': 9313.04,
#    'ClosingSecondaryCurrencyPrice': 9303.79,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T10:00:00Z',
#    'EndTimestampUtc': '2018-10-09T11:00:00Z',
#    'PrimaryCurrencyVolume': 1.6330729,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9315.3,
#    'LowestSecondaryCurrencyPrice': 9295.15,
#    'OpeningSecondaryCurrencyPrice': 9303.79,
#    'ClosingSecondaryCurrencyPrice': 9295.15,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T11:00:00Z',
#    'EndTimestampUtc': '2018-10-09T12:00:00Z',
#    'PrimaryCurrencyVolume': 5.56748936,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 9315.37,
#    'LowestSecondaryCurrencyPrice': 9299.1,
#    'OpeningSecondaryCurrencyPrice': 9295.15,
#    'ClosingSecondaryCurrencyPrice': 9309.58,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T12:00:00Z',
#    'EndTimestampUtc': '2018-10-09T13:00:00Z',
#    'PrimaryCurrencyVolume': 12.67553495,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 20,
#    'HighestSecondaryCurrencyPrice': 9309.46,
#    'LowestSecondaryCurrencyPrice': 9245.01,
#    'OpeningSecondaryCurrencyPrice': 9309.58,
#    'ClosingSecondaryCurrencyPrice': 9305.8,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T13:00:00Z',
#    'EndTimestampUtc': '2018-10-09T14:00:00Z',
#    'PrimaryCurrencyVolume': 0.35410519,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9270.62,
#    'LowestSecondaryCurrencyPrice': 9270.62,
#    'OpeningSecondaryCurrencyPrice': 9305.8,
#    'ClosingSecondaryCurrencyPrice': 9270.62,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T14:00:00Z',
#    'EndTimestampUtc': '2018-10-09T15:00:00Z',
#    'PrimaryCurrencyVolume': 0.4865129,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9279.41,
#    'LowestSecondaryCurrencyPrice': 9248.79,
#    'OpeningSecondaryCurrencyPrice': 9270.62,
#    'ClosingSecondaryCurrencyPrice': 9278.52,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T15:00:00Z',
#    'EndTimestampUtc': '2018-10-09T16:00:00Z',
#    'PrimaryCurrencyVolume': 0.71937965,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 9287.1,
#    'LowestSecondaryCurrencyPrice': 9242.63,
#    'OpeningSecondaryCurrencyPrice': 9278.52,
#    'ClosingSecondaryCurrencyPrice': 9242.63,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T16:00:00Z',
#    'EndTimestampUtc': '2018-10-09T17:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9242.63,
#    'LowestSecondaryCurrencyPrice': 9242.63,
#    'OpeningSecondaryCurrencyPrice': 9242.63,
#    'ClosingSecondaryCurrencyPrice': 9242.63,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T17:00:00Z',
#    'EndTimestampUtc': '2018-10-09T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.62529815,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9248.53,
#    'LowestSecondaryCurrencyPrice': 9244.52,
#    'OpeningSecondaryCurrencyPrice': 9242.63,
#    'ClosingSecondaryCurrencyPrice': 9246.35,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T18:00:00Z',
#    'EndTimestampUtc': '2018-10-09T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.53652608,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9273.01,
#    'LowestSecondaryCurrencyPrice': 9273.01,
#    'OpeningSecondaryCurrencyPrice': 9246.35,
#    'ClosingSecondaryCurrencyPrice': 9273.01,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T19:00:00Z',
#    'EndTimestampUtc': '2018-10-09T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.00980761,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9287.9,
#    'LowestSecondaryCurrencyPrice': 9287.9,
#    'OpeningSecondaryCurrencyPrice': 9273.01,
#    'ClosingSecondaryCurrencyPrice': 9287.9,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T20:00:00Z',
#    'EndTimestampUtc': '2018-10-09T21:00:00Z',
#    'PrimaryCurrencyVolume': 0.18919062,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 7,
#    'HighestSecondaryCurrencyPrice': 9293.08,
#    'LowestSecondaryCurrencyPrice': 9289.51,
#    'OpeningSecondaryCurrencyPrice': 9287.9,
#    'ClosingSecondaryCurrencyPrice': 9289.51,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T21:00:00Z',
#    'EndTimestampUtc': '2018-10-09T22:00:00Z',
#    'PrimaryCurrencyVolume': 8.42872591,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 17,
#    'HighestSecondaryCurrencyPrice': 9290.84,
#    'LowestSecondaryCurrencyPrice': 9225.0,
#    'OpeningSecondaryCurrencyPrice': 9289.51,
#    'ClosingSecondaryCurrencyPrice': 9225.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T22:00:00Z',
#    'EndTimestampUtc': '2018-10-09T23:00:00Z',
#    'PrimaryCurrencyVolume': 4.5876435,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 21,
#    'HighestSecondaryCurrencyPrice': 9291.76,
#    'LowestSecondaryCurrencyPrice': 9225.11,
#    'OpeningSecondaryCurrencyPrice': 9225.0,
#    'ClosingSecondaryCurrencyPrice': 9260.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-09T23:00:00Z',
#    'EndTimestampUtc': '2018-10-10T00:00:00Z',
#    'PrimaryCurrencyVolume': 8.05806035,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 26,
#    'HighestSecondaryCurrencyPrice': 9280.45,
#    'LowestSecondaryCurrencyPrice': 9248.0,
#    'OpeningSecondaryCurrencyPrice': 9260.0,
#    'ClosingSecondaryCurrencyPrice': 9250.31,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T00:00:00Z',
#    'EndTimestampUtc': '2018-10-10T01:00:00Z',
#    'PrimaryCurrencyVolume': 3.977996,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 9264.77,
#    'LowestSecondaryCurrencyPrice': 9225.0,
#    'OpeningSecondaryCurrencyPrice': 9250.31,
#    'ClosingSecondaryCurrencyPrice': 9230.01,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T01:00:00Z',
#    'EndTimestampUtc': '2018-10-10T02:00:00Z',
#    'PrimaryCurrencyVolume': 7.9164859,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 23,
#    'HighestSecondaryCurrencyPrice': 9267.86,
#    'LowestSecondaryCurrencyPrice': 9226.51,
#    'OpeningSecondaryCurrencyPrice': 9230.01,
#    'ClosingSecondaryCurrencyPrice': 9231.47,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T02:00:00Z',
#    'EndTimestampUtc': '2018-10-10T03:00:00Z',
#    'PrimaryCurrencyVolume': 7.62915483,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 31,
#    'HighestSecondaryCurrencyPrice': 9237.7,
#    'LowestSecondaryCurrencyPrice': 9191.0,
#    'OpeningSecondaryCurrencyPrice': 9231.47,
#    'ClosingSecondaryCurrencyPrice': 9220.99,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T03:00:00Z',
#    'EndTimestampUtc': '2018-10-10T04:00:00Z',
#    'PrimaryCurrencyVolume': 12.68532892,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 14,
#    'HighestSecondaryCurrencyPrice': 9199.94,
#    'LowestSecondaryCurrencyPrice': 9185.0,
#    'OpeningSecondaryCurrencyPrice': 9220.99,
#    'ClosingSecondaryCurrencyPrice': 9199.94,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T04:00:00Z',
#    'EndTimestampUtc': '2018-10-10T05:00:00Z',
#    'PrimaryCurrencyVolume': 0.73656771,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 9199.0,
#    'LowestSecondaryCurrencyPrice': 9170.0,
#    'OpeningSecondaryCurrencyPrice': 9199.94,
#    'ClosingSecondaryCurrencyPrice': 9186.66,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T05:00:00Z',
#    'EndTimestampUtc': '2018-10-10T06:00:00Z',
#    'PrimaryCurrencyVolume': 7.84861776,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 32,
#    'HighestSecondaryCurrencyPrice': 9171.82,
#    'LowestSecondaryCurrencyPrice': 9080.0,
#    'OpeningSecondaryCurrencyPrice': 9186.66,
#    'ClosingSecondaryCurrencyPrice': 9094.38,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T06:00:00Z',
#    'EndTimestampUtc': '2018-10-10T07:00:00Z',
#    'PrimaryCurrencyVolume': 7.78440066,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 19,
#    'HighestSecondaryCurrencyPrice': 9124.46,
#    'LowestSecondaryCurrencyPrice': 9075.03,
#    'OpeningSecondaryCurrencyPrice': 9094.38,
#    'ClosingSecondaryCurrencyPrice': 9112.05,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T07:00:00Z',
#    'EndTimestampUtc': '2018-10-10T08:00:00Z',
#    'PrimaryCurrencyVolume': 0.46145457,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9119.92,
#    'LowestSecondaryCurrencyPrice': 9085.49,
#    'OpeningSecondaryCurrencyPrice': 9112.05,
#    'ClosingSecondaryCurrencyPrice': 9119.92,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T08:00:00Z',
#    'EndTimestampUtc': '2018-10-10T09:00:00Z',
#    'PrimaryCurrencyVolume': 0.14045816,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 9158.61,
#    'LowestSecondaryCurrencyPrice': 9131.99,
#    'OpeningSecondaryCurrencyPrice': 9119.92,
#    'ClosingSecondaryCurrencyPrice': 9158.61,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T09:00:00Z',
#    'EndTimestampUtc': '2018-10-10T10:00:00Z',
#    'PrimaryCurrencyVolume': 0.62308174,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 9159.0,
#    'LowestSecondaryCurrencyPrice': 9147.25,
#    'OpeningSecondaryCurrencyPrice': 9158.61,
#    'ClosingSecondaryCurrencyPrice': 9159.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T10:00:00Z',
#    'EndTimestampUtc': '2018-10-10T11:00:00Z',
#    'PrimaryCurrencyVolume': 0.0738927,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9135.79,
#    'LowestSecondaryCurrencyPrice': 9107.82,
#    'OpeningSecondaryCurrencyPrice': 9159.0,
#    'ClosingSecondaryCurrencyPrice': 9124.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T11:00:00Z',
#    'EndTimestampUtc': '2018-10-10T12:00:00Z',
#    'PrimaryCurrencyVolume': 1.00482174,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 3,
#    'HighestSecondaryCurrencyPrice': 9139.67,
#    'LowestSecondaryCurrencyPrice': 9113.77,
#    'OpeningSecondaryCurrencyPrice': 9124.24,
#    'ClosingSecondaryCurrencyPrice': 9127.23,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T12:00:00Z',
#    'EndTimestampUtc': '2018-10-10T13:00:00Z',
#    'PrimaryCurrencyVolume': 0.74249998,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9192.58,
#    'LowestSecondaryCurrencyPrice': 9159.0,
#    'OpeningSecondaryCurrencyPrice': 9127.23,
#    'ClosingSecondaryCurrencyPrice': 9184.14,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T13:00:00Z',
#    'EndTimestampUtc': '2018-10-10T14:00:00Z',
#    'PrimaryCurrencyVolume': 0.25981314,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9172.68,
#    'LowestSecondaryCurrencyPrice': 9149.47,
#    'OpeningSecondaryCurrencyPrice': 9184.14,
#    'ClosingSecondaryCurrencyPrice': 9168.07,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T14:00:00Z',
#    'EndTimestampUtc': '2018-10-10T15:00:00Z',
#    'PrimaryCurrencyVolume': 0.06597704,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 9180.24,
#    'LowestSecondaryCurrencyPrice': 9180.24,
#    'OpeningSecondaryCurrencyPrice': 9168.07,
#    'ClosingSecondaryCurrencyPrice': 9180.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T15:00:00Z',
#    'EndTimestampUtc': '2018-10-10T16:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9180.24,
#    'LowestSecondaryCurrencyPrice': 9180.24,
#    'OpeningSecondaryCurrencyPrice': 9180.24,
#    'ClosingSecondaryCurrencyPrice': 9180.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T16:00:00Z',
#    'EndTimestampUtc': '2018-10-10T17:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9180.24,
#    'LowestSecondaryCurrencyPrice': 9180.24,
#    'OpeningSecondaryCurrencyPrice': 9180.24,
#    'ClosingSecondaryCurrencyPrice': 9180.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T17:00:00Z',
#    'EndTimestampUtc': '2018-10-10T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9180.24,
#    'LowestSecondaryCurrencyPrice': 9180.24,
#    'OpeningSecondaryCurrencyPrice': 9180.24,
#    'ClosingSecondaryCurrencyPrice': 9180.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T18:00:00Z',
#    'EndTimestampUtc': '2018-10-10T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.63,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 7,
#    'HighestSecondaryCurrencyPrice': 9247.81,
#    'LowestSecondaryCurrencyPrice': 9203.56,
#    'OpeningSecondaryCurrencyPrice': 9180.24,
#    'ClosingSecondaryCurrencyPrice': 9247.81,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T19:00:00Z',
#    'EndTimestampUtc': '2018-10-10T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 9247.81,
#    'LowestSecondaryCurrencyPrice': 9247.81,
#    'OpeningSecondaryCurrencyPrice': 9247.81,
#    'ClosingSecondaryCurrencyPrice': 9247.81,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-10T20:00:00Z',
#    'EndTimestampUtc': '2018-10-10T21:00:00Z',
#    'PrimaryCurrencyVolume': 1.7,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 9248.0,
# ...
#    'OpeningSecondaryCurrencyPrice': 8866.89,
#    'ClosingSecondaryCurrencyPrice': 8790.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T10:00:00Z',
#    'EndTimestampUtc': '2018-10-14T11:00:00Z',
#    'PrimaryCurrencyVolume': 2.24173443,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 10,
#    'HighestSecondaryCurrencyPrice': 8935.74,
#    'LowestSecondaryCurrencyPrice': 8786.75,
#    'OpeningSecondaryCurrencyPrice': 8790.0,
#    'ClosingSecondaryCurrencyPrice': 8788.97,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T11:00:00Z',
#    'EndTimestampUtc': '2018-10-14T12:00:00Z',
#    'PrimaryCurrencyVolume': 0.01744123,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 8785.09,
#    'LowestSecondaryCurrencyPrice': 8785.09,
#    'OpeningSecondaryCurrencyPrice': 8788.97,
#    'ClosingSecondaryCurrencyPrice': 8785.09,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T12:00:00Z',
#    'EndTimestampUtc': '2018-10-14T13:00:00Z',
#    'PrimaryCurrencyVolume': 0.37356284,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 8826.0,
#    'LowestSecondaryCurrencyPrice': 8796.62,
#    'OpeningSecondaryCurrencyPrice': 8785.09,
#    'ClosingSecondaryCurrencyPrice': 8826.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T13:00:00Z',
#    'EndTimestampUtc': '2018-10-14T14:00:00Z',
#    'PrimaryCurrencyVolume': 4.57418414,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 8817.86,
#    'LowestSecondaryCurrencyPrice': 8793.33,
#    'OpeningSecondaryCurrencyPrice': 8826.0,
#    'ClosingSecondaryCurrencyPrice': 8793.33,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T14:00:00Z',
#    'EndTimestampUtc': '2018-10-14T15:00:00Z',
#    'PrimaryCurrencyVolume': 0.5,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 8794.01,
#    'LowestSecondaryCurrencyPrice': 8794.01,
#    'OpeningSecondaryCurrencyPrice': 8793.33,
#    'ClosingSecondaryCurrencyPrice': 8794.01,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T15:00:00Z',
#    'EndTimestampUtc': '2018-10-14T16:00:00Z',
#    'PrimaryCurrencyVolume': 1.6,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 8800.07,
#    'LowestSecondaryCurrencyPrice': 8797.31,
#    'OpeningSecondaryCurrencyPrice': 8794.01,
#    'ClosingSecondaryCurrencyPrice': 8800.07,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T16:00:00Z',
#    'EndTimestampUtc': '2018-10-14T17:00:00Z',
#    'PrimaryCurrencyVolume': 1.9118921,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 8823.59,
#    'LowestSecondaryCurrencyPrice': 8800.8,
#    'OpeningSecondaryCurrencyPrice': 8800.07,
#    'ClosingSecondaryCurrencyPrice': 8800.8,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T17:00:00Z',
#    'EndTimestampUtc': '2018-10-14T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.01499355,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 8795.1,
#    'LowestSecondaryCurrencyPrice': 8795.1,
#    'OpeningSecondaryCurrencyPrice': 8800.8,
#    'ClosingSecondaryCurrencyPrice': 8795.1,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T18:00:00Z',
#    'EndTimestampUtc': '2018-10-14T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.74266953,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 8833.55,
#    'LowestSecondaryCurrencyPrice': 8797.33,
#    'OpeningSecondaryCurrencyPrice': 8795.1,
#    'ClosingSecondaryCurrencyPrice': 8833.55,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T19:00:00Z',
#    'EndTimestampUtc': '2018-10-14T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.06539,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 8851.75,
#    'LowestSecondaryCurrencyPrice': 8851.75,
#    'OpeningSecondaryCurrencyPrice': 8833.55,
#    'ClosingSecondaryCurrencyPrice': 8851.75,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T20:00:00Z',
#    'EndTimestampUtc': '2018-10-14T21:00:00Z',
#    'PrimaryCurrencyVolume': 2.36416159,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 8847.5,
#    'LowestSecondaryCurrencyPrice': 8776.83,
#    'OpeningSecondaryCurrencyPrice': 8851.75,
#    'ClosingSecondaryCurrencyPrice': 8787.34,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T21:00:00Z',
#    'EndTimestampUtc': '2018-10-14T22:00:00Z',
#    'PrimaryCurrencyVolume': 3.71220787,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 8935.39,
#    'LowestSecondaryCurrencyPrice': 8763.65,
#    'OpeningSecondaryCurrencyPrice': 8787.34,
#    'ClosingSecondaryCurrencyPrice': 8770.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T22:00:00Z',
#    'EndTimestampUtc': '2018-10-14T23:00:00Z',
#    'PrimaryCurrencyVolume': 28.76324857,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 17,
#    'HighestSecondaryCurrencyPrice': 8775.11,
#    'LowestSecondaryCurrencyPrice': 8732.28,
#    'OpeningSecondaryCurrencyPrice': 8770.0,
#    'ClosingSecondaryCurrencyPrice': 8732.28,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-14T23:00:00Z',
#    'EndTimestampUtc': '2018-10-15T00:00:00Z',
#    'PrimaryCurrencyVolume': 3.22060239,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 20,
#    'HighestSecondaryCurrencyPrice': 8728.0,
#    'LowestSecondaryCurrencyPrice': 8669.69,
#    'OpeningSecondaryCurrencyPrice': 8732.28,
#    'ClosingSecondaryCurrencyPrice': 8688.7,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T00:00:00Z',
#    'EndTimestampUtc': '2018-10-15T01:00:00Z',
#    'PrimaryCurrencyVolume': 3.91572619,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 12,
#    'HighestSecondaryCurrencyPrice': 8750.0,
#    'LowestSecondaryCurrencyPrice': 8696.86,
#    'OpeningSecondaryCurrencyPrice': 8688.7,
#    'ClosingSecondaryCurrencyPrice': 8750.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T01:00:00Z',
#    'EndTimestampUtc': '2018-10-15T02:00:00Z',
#    'PrimaryCurrencyVolume': 3.82116897,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 8750.0,
#    'LowestSecondaryCurrencyPrice': 8734.55,
#    'OpeningSecondaryCurrencyPrice': 8750.0,
#    'ClosingSecondaryCurrencyPrice': 8750.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T02:00:00Z',
#    'EndTimestampUtc': '2018-10-15T03:00:00Z',
#    'PrimaryCurrencyVolume': 4.17815573,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 16,
#    'HighestSecondaryCurrencyPrice': 8789.49,
#    'LowestSecondaryCurrencyPrice': 8740.67,
#    'OpeningSecondaryCurrencyPrice': 8750.0,
#    'ClosingSecondaryCurrencyPrice': 8746.24,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T03:00:00Z',
#    'EndTimestampUtc': '2018-10-15T04:00:00Z',
#    'PrimaryCurrencyVolume': 0.77713428,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 6,
#    'HighestSecondaryCurrencyPrice': 8793.86,
#    'LowestSecondaryCurrencyPrice': 8754.34,
#    'OpeningSecondaryCurrencyPrice': 8746.24,
#    'ClosingSecondaryCurrencyPrice': 8793.86,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T04:00:00Z',
#    'EndTimestampUtc': '2018-10-15T05:00:00Z',
#    'PrimaryCurrencyVolume': 3.00352187,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 11,
#    'HighestSecondaryCurrencyPrice': 8787.35,
#    'LowestSecondaryCurrencyPrice': 8750.0,
#    'OpeningSecondaryCurrencyPrice': 8793.86,
#    'ClosingSecondaryCurrencyPrice': 8750.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T05:00:00Z',
#    'EndTimestampUtc': '2018-10-15T06:00:00Z',
#    'PrimaryCurrencyVolume': 21.06491939,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 69,
#    'HighestSecondaryCurrencyPrice': 9136.78,
#    'LowestSecondaryCurrencyPrice': 8750.0,
#    'OpeningSecondaryCurrencyPrice': 8750.0,
#    'ClosingSecondaryCurrencyPrice': 9061.81,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T06:00:00Z',
#    'EndTimestampUtc': '2018-10-15T07:00:00Z',
#    'PrimaryCurrencyVolume': 58.57583299,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 194,
#    'HighestSecondaryCurrencyPrice': 9423.53,
#    'LowestSecondaryCurrencyPrice': 9068.61,
#    'OpeningSecondaryCurrencyPrice': 9061.81,
#    'ClosingSecondaryCurrencyPrice': 9405.14,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T07:00:00Z',
#    'EndTimestampUtc': '2018-10-15T08:00:00Z',
#    'PrimaryCurrencyVolume': 39.48319148,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 217,
#    'HighestSecondaryCurrencyPrice': 9405.15,
#    'LowestSecondaryCurrencyPrice': 9000.0,
#    'OpeningSecondaryCurrencyPrice': 9405.14,
#    'ClosingSecondaryCurrencyPrice': 9000.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T08:00:00Z',
#    'EndTimestampUtc': '2018-10-15T09:00:00Z',
#    'PrimaryCurrencyVolume': 13.61219905,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 29,
#    'HighestSecondaryCurrencyPrice': 9104.78,
#    'LowestSecondaryCurrencyPrice': 8935.65,
#    'OpeningSecondaryCurrencyPrice': 9000.0,
#    'ClosingSecondaryCurrencyPrice': 9010.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T09:00:00Z',
#    'EndTimestampUtc': '2018-10-15T10:00:00Z',
#    'PrimaryCurrencyVolume': 13.03180395,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 23,
#    'HighestSecondaryCurrencyPrice': 8991.88,
#    'LowestSecondaryCurrencyPrice': 8885.47,
#    'OpeningSecondaryCurrencyPrice': 9010.0,
#    'ClosingSecondaryCurrencyPrice': 8991.82,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T10:00:00Z',
#    'EndTimestampUtc': '2018-10-15T11:00:00Z',
#    'PrimaryCurrencyVolume': 4.37122028,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9001.59,
#    'LowestSecondaryCurrencyPrice': 8932.38,
#    'OpeningSecondaryCurrencyPrice': 8991.82,
#    'ClosingSecondaryCurrencyPrice': 8968.01,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T11:00:00Z',
#    'EndTimestampUtc': '2018-10-15T12:00:00Z',
#    'PrimaryCurrencyVolume': 1.73032108,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 8,
#    'HighestSecondaryCurrencyPrice': 9031.81,
#    'LowestSecondaryCurrencyPrice': 8935.88,
#    'OpeningSecondaryCurrencyPrice': 8968.01,
#    'ClosingSecondaryCurrencyPrice': 8950.51,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T12:00:00Z',
#    'EndTimestampUtc': '2018-10-15T13:00:00Z',
#    'PrimaryCurrencyVolume': 30.20021,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 29,
#    'HighestSecondaryCurrencyPrice': 8944.74,
#    'LowestSecondaryCurrencyPrice': 8922.05,
#    'OpeningSecondaryCurrencyPrice': 8950.51,
#    'ClosingSecondaryCurrencyPrice': 8928.49,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T13:00:00Z',
#    'EndTimestampUtc': '2018-10-15T14:00:00Z',
#    'PrimaryCurrencyVolume': 7.81966764,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 8919.25,
#    'LowestSecondaryCurrencyPrice': 8897.99,
#    'OpeningSecondaryCurrencyPrice': 8928.49,
#    'ClosingSecondaryCurrencyPrice': 8919.25,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T14:00:00Z',
#    'EndTimestampUtc': '2018-10-15T15:00:00Z',
#    'PrimaryCurrencyVolume': 0.972,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 2,
#    'HighestSecondaryCurrencyPrice': 8907.22,
#    'LowestSecondaryCurrencyPrice': 8907.22,
#    'OpeningSecondaryCurrencyPrice': 8919.25,
#    'ClosingSecondaryCurrencyPrice': 8907.22,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T15:00:00Z',
#    'EndTimestampUtc': '2018-10-15T16:00:00Z',
#    'PrimaryCurrencyVolume': 9.787,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 5,
#    'HighestSecondaryCurrencyPrice': 8901.43,
#    'LowestSecondaryCurrencyPrice': 8872.45,
#    'OpeningSecondaryCurrencyPrice': 8907.22,
#    'ClosingSecondaryCurrencyPrice': 8898.14,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T16:00:00Z',
#    'EndTimestampUtc': '2018-10-15T17:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 8898.14,
#    'LowestSecondaryCurrencyPrice': 8898.14,
#    'OpeningSecondaryCurrencyPrice': 8898.14,
#    'ClosingSecondaryCurrencyPrice': 8898.14,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T17:00:00Z',
#    'EndTimestampUtc': '2018-10-15T18:00:00Z',
#    'PrimaryCurrencyVolume': 0.0,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 0,
#    'HighestSecondaryCurrencyPrice': 8898.14,
#    'LowestSecondaryCurrencyPrice': 8898.14,
#    'OpeningSecondaryCurrencyPrice': 8898.14,
#    'ClosingSecondaryCurrencyPrice': 8898.14,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T18:00:00Z',
#    'EndTimestampUtc': '2018-10-15T19:00:00Z',
#    'PrimaryCurrencyVolume': 0.011,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 1,
#    'HighestSecondaryCurrencyPrice': 8977.57,
#    'LowestSecondaryCurrencyPrice': 8977.57,
#    'OpeningSecondaryCurrencyPrice': 8898.14,
#    'ClosingSecondaryCurrencyPrice': 8977.57,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T19:00:00Z',
#    'EndTimestampUtc': '2018-10-15T20:00:00Z',
#    'PrimaryCurrencyVolume': 0.16387861,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 4,
#    'HighestSecondaryCurrencyPrice': 8945.0,
#    'LowestSecondaryCurrencyPrice': 8943.51,
#    'OpeningSecondaryCurrencyPrice': 8977.57,
#    'ClosingSecondaryCurrencyPrice': 8945.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T20:00:00Z',
#    'EndTimestampUtc': '2018-10-15T21:00:00Z',
#    'PrimaryCurrencyVolume': 1.83219115,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 15,
#    'HighestSecondaryCurrencyPrice': 8982.8,
#    'LowestSecondaryCurrencyPrice': 8945.0,
#    'OpeningSecondaryCurrencyPrice': 8945.0,
#    'ClosingSecondaryCurrencyPrice': 8969.33,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T21:00:00Z',
#    'EndTimestampUtc': '2018-10-15T22:00:00Z',
#    'PrimaryCurrencyVolume': 2.27528433,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 13,
#    'HighestSecondaryCurrencyPrice': 8961.29,
#    'LowestSecondaryCurrencyPrice': 8905.29,
#    'OpeningSecondaryCurrencyPrice': 8969.33,
#    'ClosingSecondaryCurrencyPrice': 8940.0,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T22:00:00Z',
#    'EndTimestampUtc': '2018-10-15T23:00:00Z',
#    'PrimaryCurrencyVolume': 4.2371176,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 19,
#    'HighestSecondaryCurrencyPrice': 9067.41,
#    'LowestSecondaryCurrencyPrice': 8923.41,
#    'OpeningSecondaryCurrencyPrice': 8940.0,
#    'ClosingSecondaryCurrencyPrice': 9010.37,
#    'AverageSecondaryCurrencyPrice': 0.0},
#   {'StartTimestampUtc': '2018-10-15T23:00:00Z',
#    'EndTimestampUtc': '2018-10-16T00:00:00Z',
#    'PrimaryCurrencyVolume': 10.01725845,
#    'SecondaryCurrencyVolume': 0.0,
#    'NumberOfTrades': 21,
#    'HighestSecondaryCurrencyPrice': 9037.01,
#    'LowestSecondaryCurrencyPrice': 8986.19,
#    'OpeningSecondaryCurrencyPrice': 9010.37,
#    'ClosingSecondaryCurrencyPrice': 9036.88,
#    'AverageSecondaryCurrencyPrice': 0.0}],
#  'NumberOfHoursInThePastToRetrieve': 240,
#  'PrimaryCurrencyCode': 'Xbt',
#  'SecondaryCurrencyCode': 'Aud',
#  'CreatedTimestampUtc': '2018-10-16T00:30:43.8700284Z'}
